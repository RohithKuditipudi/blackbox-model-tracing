# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy

# %%
# reading PPLX over batch size ablations

df = pd.read_csv('./tinystories_rohith/bs_pplx.csv')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
# path to a reference model eval results (rohith's pplx 0)
df_ref = pd.read_csv('rohith_data.csv')
df['reference'] = df_ref['pplx_0']

# %%
# number of eval samples
sizes = [1000, 2000, 3000,5000, 8000, 10000]

# %%
# doing some normalization for each column individually because pplx across diff batch sizes is very big
# normalize to mean 0, std 1

for col in df.keys():
    normalized = (df[col] - np.mean(df[col])) / np.std(df[col])
    df[f'{col}-norm'] = normalized

# %%
# adding index column that was the training order

df['index'] = np.arange(len(df))
df = df.sample(frac=1)
df
# Out:
#       pplx-bs-64  pplx-bs-32  pplx-bs-16  pplx-bs-8  pplx-bs-4  pplx-bs-2  \
# 1452   10.314301   10.017136    9.528364   8.878372   7.784433   6.554020
# 15     10.372677    9.967843    9.546595   8.905780   7.841452   6.715866
# 209    10.265486    9.972073    9.351317   8.639534   7.362968   5.899269
# 1012   10.363297    9.984930    9.483525   8.839090   7.604562   6.342249
# 673    10.322906    9.964190    9.442597   8.781778   7.501890   6.230874
# ...          ...         ...         ...        ...        ...        ...
# 1678   10.307441    9.902808    9.508540   8.844811   7.569528   6.295292
# 822    10.401747    9.960578    9.562215   8.943846   7.891482   6.690521
# 1260   10.299679    9.980525    9.497589   8.860010   7.671956   6.380945
# 676    10.273829    9.975575    9.503288   8.801969   7.637818   6.389085
# 2873   10.318501    9.974395    9.530415   8.841563   7.695004   6.398164
#
#       pplx-bs-1  pplx-bs-64-norm  pplx-bs-32-norm  pplx-bs-16-norm  \
# 1452   5.860248         0.497079         0.872757         0.839790
# 15     5.979249         1.924875        -0.154440         1.106867
# 209    4.746704        -0.696899        -0.066301        -1.753957
# 1012   5.469908         1.695467         0.201632         0.182898
# 673    5.368395         0.707526        -0.230554        -0.416699
# ...         ...              ...              ...              ...
# 1678   5.405642         0.329274        -1.509682         0.549367
# 822    6.118791         2.635894        -0.305833         1.335706
# 1260   5.340409         0.139425         0.109837         0.388934
# 676    5.723594        -0.492822         0.006695         0.472426
# 2873   5.601822         0.599806        -0.017909         0.869828
#
#       pplx-bs-8-norm  pplx-bs-4-norm  pplx-bs-2-norm  pplx-bs-1-norm  index
# 1452        1.054081        1.109521        1.034917        1.169092   1452
# 15          1.378799        1.610205        1.897142        1.562576     15
# 209        -1.775615       -2.591348       -2.453239       -2.512930    209
# 1012        0.588679       -0.469922       -0.093286       -0.121597   1012
# 673        -0.090340       -1.371481       -0.686630       -0.457259    673
# ...              ...             ...             ...             ...    ...
# 1678        0.656461       -0.777551       -0.343447       -0.334099   1678
# 822         1.829794        2.049515        1.762119        2.023985    822
# 1260        0.836532        0.121865        0.112867       -0.549798   1260
# 676         0.148870       -0.177901        0.156233        0.717234    676
# 2873        0.617976        0.324249        0.204601        0.314587   2873
#
# [3000 rows x 15 columns]

# %%
batch_sizes = [1, 2, 4, 8, 16, 32, 64]

table = pd.DataFrame({}) # table to display results
table['batch_size'] = batch_sizes

for size in sizes:
    temp = []
    for bs in batch_sizes:
        temp.append(f'{scipy.stats.spearmanr(df['index'][:size], 
                                       df[f'pplx-bs-{bs}-norm'][:size] - df['reference-norm'][:size])[1]:.4e}')
    table[f'{size} samples'] = temp

table
# Out:
#   Cell In[9], line 9
#     temp.append(f'{scipy.stats.spearmanr(df['index'][:size],
#                                              ^
# SyntaxError: f-string: unmatched '['
